# %% [markdown]
# <a href="https://colab.research.google.com/github/wakepon21/Masa/blob/ngrok/ngrok_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 事前準備
# * ngrokの会員登録
# * google driveの会員登録
# * sshキーを生成し公開鍵をcolab.pubとしてgoogle drive直下に置く
# * このnotebook末尾のセルの中身をsshd_configと名付けてgoogle drive直下に置く

# %%
import os, sys
from google.colab import drive

# %%
# !pip3 install colab_ssh --upgrade
# Out:
# Collecting colab_ssh
#   Downloading https://files.pythonhosted.org/packages/bf/46/6ef2cefc686bf8cfdf3464232f4d07c53657b62dfff934b3e2c8c349a263/colab_ssh-0.2.60-py3-none-any.whl
# Installing collected packages: colab-ssh
# Successfully installed colab-ssh-0.2.60

# %%
from colab_ssh import launch_ssh
launch_ssh('1h7O6mX0VeaYFfHzWtSwSQWDNVS_7QMahcSyBkLFUC9MhEbeJ', 'MtiG5fUYz9kdbWti0Gdl')
# Out:
# Successfully running 0.tcp.ngrok.io:15200
# [Optional] You can also connect with VSCode SSH Remote extension using this configuration:
#
# 	Host google_colab_ssh
# 		HostName 0.tcp.ngrok.io
# 		User root
# 		Port 15200

# %% [markdown]
# **sshのconfigに下の内容を追加**
#
# ```
# Host colab
#   HostName 0.tcp.ngrok.io
#   Port 19515
#   User root
#   ServerAliveInterval 20
#   LocalForward 8888 localhost:8888
#   IdentityFile "/path/to/secret_key"
# ```
# なお、HostNameの最初の数字とPortは毎回変わるので、configはそこだけ毎回書き換える必要がある
#
# 下のセルを実行開始し、sshでcolabにつなぐ。実行は終わらないのでsshはすぐにつないでよい

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mkdir "/root/.ssh"
# !echo "setting up ssh"
# !cp "/content/drive/My Drive/colab.pub" /root/.ssh/authorized_keys
# !chmod 600 /root/.ssh/authorized_keys
# !chmod 644 /root/.ssh
# !cp "/content/drive/My Drive/sshd_config" /etc/ssh/sshd_config

# !echo "installing nodejs"
# !apt -y install curl dirmngr apt-transport-https lsb-release ca-certificates neovim
# !curl -sL https://deb.nodesource.com/setup_12.x | sudo -E bash -
# !apt -y install nodejs

# !echo "installing jupyterlab"
# !pip3 install jupyterlab
# !cd "/content/notebooks/"
# !echo "launching jupyter"
# !jupyter lab --port 8888 --ip=0.0.0.0 --allow-root
# Out:
# setting up ssh
# installing nodejs
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# lsb-release is already the newest version (9.20170808ubuntu1).
# lsb-release set to manually installed.
# ca-certificates is already the newest version (20190110~18.04.1).
# curl is already the newest version (7.58.0-2ubuntu3.10).
# dirmngr is already the newest version (2.2.4-1ubuntu1.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   javascript-common libjemalloc1 libjs-jquery libjs-sphinxdoc libjs-underscore
#   libmsgpackc2 libtermkey1 libunibilium4 libvterm0 neovim-runtime
#   python-concurrent.futures python-greenlet python-msgpack python-neovim
#   python-six python-trollius python3-greenlet python3-msgpack python3-neovim
#   xxd
# Suggested packages:
#   apache2 | lighttpd | httpd ctags vim-scripts python-greenlet-doc
#   python-greenlet-dev python-greenlet-dbg python3-greenlet-dbg
# The following NEW packages will be installed:
#   apt-transport-https javascript-common libjemalloc1 libjs-jquery
#   libjs-sphinxdoc libjs-underscore libmsgpackc2 libtermkey1 libunibilium4
#   libvterm0 neovim neovim-runtime python-concurrent.futures python-greenlet
#   python-msgpack python-neovim python-six python-trollius python3-greenlet
#   python3-msgpack python3-neovim xxd
# 0 upgraded, 22 newly installed, 0 to remove and 39 not upgraded.
# Need to get 4,991 kB of archives.
# After this operation, 23.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xxd amd64 2:8.0.1453-1ubuntu1.3 [49.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 apt-transport-https all 1.6.12ubuntu0.1 [1,692 B]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-underscore all 1.8.3~dfsg-1 [59.9 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-sphinxdoc all 1.6.7-1ubuntu1 [85.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libunibilium4 amd64 2.0.0-2 [22.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-concurrent.futures all 3.2.0-1 [34.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-msgpack amd64 0.5.6-1 [73.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-greenlet amd64 0.4.12-2 [18.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-six all 1.11.0-2 [11.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-trollius all 2.1~b1-5 [83.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-neovim all 0.2.0-1 [28.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-msgpack amd64 0.5.6-1 [73.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-greenlet amd64 0.4.12-2 [15.2 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-neovim all 0.2.0-1 [29.0 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjemalloc1 amd64 3.6.0-11 [82.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmsgpackc2 amd64 2.1.5-1 [14.3 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libtermkey1 amd64 0.20-3 [18.4 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libvterm0 amd64 0~bzr715-1 [28.3 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 neovim-runtime all 0.2.2-3 [3,047 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/universe amd64 neovim amd64 0.2.2-3 [1,056 kB]
# Fetched 4,991 kB in 2s (2,669 kB/s)
# Selecting previously unselected package xxd.
# (Reading database ... 147596 files and directories currently installed.)
# Preparing to unpack .../00-xxd_2%3a8.0.1453-1ubuntu1.3_amd64.deb ...
# Unpacking xxd (2:8.0.1453-1ubuntu1.3) ...
# Selecting previously unselected package apt-transport-https.
# Preparing to unpack .../01-apt-transport-https_1.6.12ubuntu0.1_all.deb ...
# Unpacking apt-transport-https (1.6.12ubuntu0.1) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../02-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../03-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../04-libjs-underscore_1.8.3~dfsg-1_all.deb ...
# Unpacking libjs-underscore (1.8.3~dfsg-1) ...
# Selecting previously unselected package libjs-sphinxdoc.
# Preparing to unpack .../05-libjs-sphinxdoc_1.6.7-1ubuntu1_all.deb ...
# Unpacking libjs-sphinxdoc (1.6.7-1ubuntu1) ...
# Selecting previously unselected package libunibilium4:amd64.
# Preparing to unpack .../06-libunibilium4_2.0.0-2_amd64.deb ...
# Unpacking libunibilium4:amd64 (2.0.0-2) ...
# Selecting previously unselected package python-concurrent.futures.
# Preparing to unpack .../07-python-concurrent.futures_3.2.0-1_all.deb ...
# Unpacking python-concurrent.futures (3.2.0-1) ...
# Selecting previously unselected package python-msgpack.
# Preparing to unpack .../08-python-msgpack_0.5.6-1_amd64.deb ...
# Unpacking python-msgpack (0.5.6-1) ...
# Selecting previously unselected package python-greenlet.
# Preparing to unpack .../09-python-greenlet_0.4.12-2_amd64.deb ...
# Unpacking python-greenlet (0.4.12-2) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../10-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-trollius.
# Preparing to unpack .../11-python-trollius_2.1~b1-5_all.deb ...
# Unpacking python-trollius (2.1~b1-5) ...
# Selecting previously unselected package python-neovim.
# Preparing to unpack .../12-python-neovim_0.2.0-1_all.deb ...
# Unpacking python-neovim (0.2.0-1) ...
# Selecting previously unselected package python3-msgpack.
# Preparing to unpack .../13-python3-msgpack_0.5.6-1_amd64.deb ...
# Unpacking python3-msgpack (0.5.6-1) ...
# Selecting previously unselected package python3-greenlet.
# Preparing to unpack .../14-python3-greenlet_0.4.12-2_amd64.deb ...
# Unpacking python3-greenlet (0.4.12-2) ...
# Selecting previously unselected package python3-neovim.
# Preparing to unpack .../15-python3-neovim_0.2.0-1_all.deb ...
# Unpacking python3-neovim (0.2.0-1) ...
# Selecting previously unselected package libjemalloc1.
# Preparing to unpack .../16-libjemalloc1_3.6.0-11_amd64.deb ...
# Unpacking libjemalloc1 (3.6.0-11) ...
# Selecting previously unselected package libmsgpackc2:amd64.
# Preparing to unpack .../17-libmsgpackc2_2.1.5-1_amd64.deb ...
# Unpacking libmsgpackc2:amd64 (2.1.5-1) ...
# Selecting previously unselected package libtermkey1:amd64.
# Preparing to unpack .../18-libtermkey1_0.20-3_amd64.deb ...
# Unpacking libtermkey1:amd64 (0.20-3) ...
# Selecting previously unselected package libvterm0:amd64.
# Preparing to unpack .../19-libvterm0_0~bzr715-1_amd64.deb ...
# Unpacking libvterm0:amd64 (0~bzr715-1) ...
# Selecting previously unselected package neovim-runtime.
# Preparing to unpack .../20-neovim-runtime_0.2.2-3_all.deb ...
# Unpacking neovim-runtime (0.2.2-3) ...
# Selecting previously unselected package neovim.
# Preparing to unpack .../21-neovim_0.2.2-3_amd64.deb ...
# Unpacking neovim (0.2.2-3) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up python-msgpack (0.5.6-1) ...
# Setting up apt-transport-https (1.6.12ubuntu0.1) ...
# Setting up libjs-underscore (1.8.3~dfsg-1) ...
# Setting up python3-greenlet (0.4.12-2) ...
# Setting up xxd (2:8.0.1453-1ubuntu1.3) ...
# Setting up libjemalloc1 (3.6.0-11) ...
# Setting up neovim-runtime (0.2.2-3) ...
# Setting up libunibilium4:amd64 (2.0.0-2) ...
# Setting up python3-msgpack (0.5.6-1) ...
# Setting up libtermkey1:amd64 (0.20-3) ...
# Setting up libjs-sphinxdoc (1.6.7-1ubuntu1) ...
# Setting up python-six (1.11.0-2) ...
# Setting up libvterm0:amd64 (0~bzr715-1) ...
# Setting up python-greenlet (0.4.12-2) ...
# Setting up python-concurrent.futures (3.2.0-1) ...
# Setting up javascript-common (11) ...
# Setting up python3-neovim (0.2.0-1) ...
# Setting up libmsgpackc2:amd64 (2.1.5-1) ...
# Setting up python-trollius (2.1~b1-5) ...
# Setting up neovim (0.2.2-3) ...
# update-alternatives: using /usr/bin/nvim to provide /usr/bin/editor (editor) in auto mode
# update-alternatives: using /usr/bin/ex.nvim to provide /usr/bin/ex (ex) in auto mode
# update-alternatives: using /usr/bin/rvim.nvim to provide /usr/bin/rvim (rvim) in auto mode
# update-alternatives: using /usr/bin/rview.nvim to provide /usr/bin/rview (rview) in auto mode
# update-alternatives: using /usr/bin/nvim to provide /usr/bin/vi (vi) in auto mode
# update-alternatives: using /usr/bin/nvim to provide /usr/bin/vim (vim) in auto mode
# update-alternatives: using /usr/bin/view.nvim to provide /usr/bin/view (view) in auto mode
# update-alternatives: using /usr/bin/vimdiff.nvim to provide /usr/bin/vimdiff (vimdiff) in auto mode
# Setting up python-neovim (0.2.0-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
#
# ## Installing the NodeSource Node.js 12.x repo...
#
#
# ## Populating apt-get cache...
#
# + apt-get update
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [95.7 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [47.5 kB]
# Hit:12 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:14 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,067 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [43.0 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,421 kB]
# Get:19 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,864 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [109 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [892 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,362 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [125 kB]
# Get:24 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [900 kB]
# Fetched 8,220 kB in 4s (2,224 kB/s)
# Reading package lists... Done
#
# ## Confirming "bionic" is supported...
#
# + curl -sLf -o /dev/null 'https://deb.nodesource.com/node_12.x/dists/bionic/Release'
#
# ## Adding the NodeSource signing key to your keyring...
#
# + curl -s https://deb.nodesource.com/gpgkey/nodesource.gpg.key | apt-key add -
# OK
#
# ## Creating apt sources list file for the NodeSource Node.js 12.x repo...
#
# + echo 'deb https://deb.nodesource.com/node_12.x bionic main' > /etc/apt/sources.list.d/nodesource.list
# + echo 'deb-src https://deb.nodesource.com/node_12.x bionic main' >> /etc/apt/sources.list.d/nodesource.list
#
# ## Running `apt-get update` for you...
#
# + apt-get update
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Get:2 https://deb.nodesource.com/node_12.x bionic InRelease [4,584 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:9 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:12 https://deb.nodesource.com/node_12.x bionic/main amd64 Packages [767 B]
# Hit:13 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:15 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease
# Fetched 5,351 B in 1s (6,723 B/s)
# Reading package lists... Done
#
# ## Run `sudo apt-get install -y nodejs` to install Node.js 12.x and npm
# ## You may also need development tools to build native addons:
#      sudo apt-get install gcc g++ make
# ## To install the Yarn package manager, run:
#      curl -sL https://dl.yarnpkg.com/debian/pubkey.gpg | sudo apt-key add -
#      echo "deb https://dl.yarnpkg.com/debian/ stable main" | sudo tee /etc/apt/sources.list.d/yarn.list
#      sudo apt-get update && sudo apt-get install yarn
#
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 72 not upgraded.
# Need to get 18.2 MB of archives.
# After this operation, 92.3 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_12.x bionic/main amd64 nodejs amd64 12.18.3-1nodesource1 [18.2 MB]
# Fetched 18.2 MB in 0s (59.6 MB/s)
# Selecting previously unselected package nodejs.
# (Reading database ... 149333 files and directories currently installed.)
# Preparing to unpack .../nodejs_12.18.3-1nodesource1_amd64.deb ...
# Unpacking nodejs (12.18.3-1nodesource1) ...
# Setting up nodejs (12.18.3-1nodesource1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# installing jupyterlab
# Collecting jupyterlab
#   Downloading https://files.pythonhosted.org/packages/0c/2e/1bea5f1cb8ebb2db6e0b05887fa8a4f4e8f253ca20e139e7997e80196c3b/jupyterlab-2.2.6-py3-none-any.whl (7.8MB)
#      |████████████████████████████████| 7.8MB 3.6MB/s
# Collecting jupyterlab-server<2.0,>=1.1.5
#   Downloading https://files.pythonhosted.org/packages/b4/eb/560043dcd8376328f8b98869efed66ef68307278406ab99c7f63a34d4ae2/jupyterlab_server-1.2.0-py3-none-any.whl
# Requirement already satisfied: tornado!=6.0.0,!=6.0.1,!=6.0.2 in /usr/local/lib/python3.6/dist-packages (from jupyterlab) (5.1.1)
# Requirement already satisfied: jinja2>=2.10 in /usr/local/lib/python3.6/dist-packages (from jupyterlab) (2.11.2)
# Requirement already satisfied: notebook>=4.3.1 in /usr/local/lib/python3.6/dist-packages (from jupyterlab) (5.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab) (2.23.0)
# Collecting json5
#   Downloading https://files.pythonhosted.org/packages/2b/81/22bf51a5bc60dde18bb6164fd597f18ee683de8670e141364d9c432dd3cf/json5-0.9.5-py2.py3-none-any.whl
# Collecting jsonschema>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
#      |████████████████████████████████| 61kB 9.8MB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2>=2.10->jupyterlab) (1.1.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.6/dist-packages (from notebook>=4.3.1->jupyterlab) (5.0.7)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.3.1->jupyterlab) (4.6.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from notebook>=4.3.1->jupyterlab) (1.5.0)
# Requirement already satisfied: jupyter-client>=5.2.0 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.3.1->jupyterlab) (5.3.5)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.3.1->jupyterlab) (4.3.3)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from notebook>=4.3.1->jupyterlab) (4.10.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.3.1->jupyterlab) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.3.1->jupyterlab) (0.8.3)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from notebook>=4.3.1->jupyterlab) (0.2.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab) (3.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab) (49.6.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab) (0.16.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab) (1.7.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab) (20.1.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab) (1.15.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client>=5.2.0->notebook>=4.3.1->jupyterlab) (19.0.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client>=5.2.0->notebook>=4.3.1->jupyterlab) (2.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2.1->notebook>=4.3.1->jupyterlab) (4.4.2)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel->notebook>=4.3.1->jupyterlab) (5.5.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.3.1->jupyterlab) (2.1.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.3.1->jupyterlab) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.3.1->jupyterlab) (1.4.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.3.1->jupyterlab) (3.1.5)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.3.1->jupyterlab) (0.4.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.3.1->jupyterlab) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.3.1->jupyterlab) (0.8.4)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /usr/local/lib/python3.6/dist-packages (from terminado>=0.8.1->notebook>=4.3.1->jupyterlab) (0.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab) (3.1.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.3.1->jupyterlab) (0.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.3.1->jupyterlab) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.3.1->jupyterlab) (1.0.18)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.3.1->jupyterlab) (4.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.3.1->jupyterlab) (20.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.3.1->jupyterlab) (0.5.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipykernel->notebook>=4.3.1->jupyterlab) (0.2.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->bleach->nbconvert->notebook>=4.3.1->jupyterlab) (2.4.7)
# Installing collected packages: json5, jsonschema, jupyterlab-server, jupyterlab
#   Found existing installation: jsonschema 2.6.0
#     Uninstalling jsonschema-2.6.0:
#       Successfully uninstalled jsonschema-2.6.0
# Successfully installed json5-0.9.5 jsonschema-3.2.0 jupyterlab-2.2.6 jupyterlab-server-1.2.0
# /bin/bash: line 0: cd: /content/notebooks/: No such file or directory
# launching jupyter
# |DEBUG|Paths used for configuration of jupyter_notebook_config:
#     	/etc/jupyter/jupyter_notebook_config.json
# |DEBUG|Paths used for configuration of jupyter_notebook_config:
#     	/usr/local/etc/jupyter/jupyter_notebook_config.d/jupyterlab.json
#     	/usr/local/etc/jupyter/jupyter_notebook_config.json
# |DEBUG|Paths used for configuration of jupyter_notebook_config:
#     	/usr/etc/jupyter/jupyter_notebook_config.json
# |DEBUG|Paths used for configuration of jupyter_notebook_config:
#     	/root/.jupyter/jupyter_notebook_config.json
# |INFO|google.colab serverextension initialized.
# |INFO|JupyterLab extension loaded from /usr/local/lib/python3.6/dist-packages/jupyterlab
# |INFO|JupyterLab application directory is /usr/local/share/jupyter/lab
# |WARNING|JupyterLab server extension not enabled, manually loading...
# |INFO|JupyterLab extension loaded from /usr/local/lib/python3.6/dist-packages/jupyterlab
# |INFO|JupyterLab application directory is /usr/local/share/jupyter/lab
# |INFO|Serving notebooks from local directory: /content
# |INFO|0 active kernels
# |INFO|The Jupyter Notebook is running at:
# |INFO|http://0.0.0.0:8888/
# |INFO|Use Control-C to stop this server and shut down all kernels (twice to skip confirmation).
# |INFO|302 GET / (127.0.0.1) 0.75ms
# |DEBUG|Using contents: services/contents
# |DEBUG|200 GET /lab? (127.0.0.1) 14.63ms
# |DEBUG|Path main.7aaa2340f7c631eb6cc8.js served from /usr/local/share/jupyter/lab/static/main.7aaa2340f7c631eb6cc8.js
# |DEBUG|200 GET /static/lab/main.7aaa2340f7c631eb6cc8.js (127.0.0.1) 1.54ms
# |DEBUG|Path vendors~main.d6ae31c7fff1f92f0bb6.js served from /usr/local/share/jupyter/lab/static/vendors~main.d6ae31c7fff1f92f0bb6.js
# |DEBUG|200 GET /static/lab/vendors~main.d6ae31c7fff1f92f0bb6.js (127.0.0.1) 11.37ms
# |DEBUG|200 GET /lab/api/settings/?1599369221477 (127.0.0.1) 18.63ms
# |DEBUG|Found kernel python2 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel python3 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel ir in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel swift in /usr/local/share/jupyter/kernels
# |DEBUG|200 GET /api/kernelspecs?1599369221470 (127.0.0.1) 4.15ms
# |DEBUG|200 GET /api/kernels?1599369221517 (127.0.0.1) 0.91ms
# |DEBUG|200 GET /api/sessions?1599369221519 (127.0.0.1) 1.05ms
# |DEBUG|200 GET /api/terminals?1599369221520 (127.0.0.1) 0.56ms
# |DEBUG|Path base/images/favicon.ico served from /usr/local/lib/python3.6/dist-packages/notebook/static/base/images/favicon.ico
# |DEBUG|200 GET /static/base/images/favicon.ico (127.0.0.1) 3.50ms
# |DEBUG|Node v12.18.3
#
# |DEBUG|200 GET /api/nbconvert?1599369221954 (127.0.0.1) 104.99ms
# |DEBUG|200 GET /api/nbconvert?1599369221981 (127.0.0.1) 1.46ms
# |DEBUG|Using contents: services/contents
# |DEBUG|Path components/jquery-ui/themes/smoothness/jquery-ui.min.css served from /usr/local/lib/python3.6/dist-packages/notebook/static/components/jquery-ui/themes/smoothness/jquery-ui.min.css
# |DEBUG|Path components/jquery-typeahead/dist/jquery.typeahead.min.css served from /usr/local/lib/python3.6/dist-packages/notebook/static/components/jquery-typeahead/dist/jquery.typeahead.min.css
# |DEBUG|Path style/style.min.css served from /usr/local/lib/python3.6/dist-packages/notebook/static/style/style.min.css
# |DEBUG|Path components/es6-promise/promise.min.js served from /usr/local/lib/python3.6/dist-packages/notebook/static/components/es6-promise/promise.min.js
# |DEBUG|Path components/preact/index.js served from /usr/local/lib/python3.6/dist-packages/notebook/static/components/preact/index.js
# |DEBUG|Path components/proptypes/index.js served from /usr/local/lib/python3.6/dist-packages/notebook/static/components/proptypes/index.js
# |DEBUG|Path components/preact-compat/index.js served from /usr/local/lib/python3.6/dist-packages/notebook/static/components/preact-compat/index.js
# |DEBUG|Path components/requirejs/require.js served from /usr/local/lib/python3.6/dist-packages/notebook/static/components/requirejs/require.js
# |DEBUG|Path base/images/logo.png served from /usr/local/lib/python3.6/dist-packages/notebook/static/base/images/logo.png
# |WARNING|404 GET /metrics?1599369222004 (127.0.0.1) 64.26ms referer=http://localhost:8888/lab?
# |DEBUG|Found kernel python2 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel python3 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel ir in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel swift in /usr/local/share/jupyter/kernels
# |DEBUG|200 GET /api/kernelspecs?1599369222006 (127.0.0.1) 4.31ms
# |DEBUG|Path @jupyterlab/theme-light-extension/index.css served from /usr/local/share/jupyter/lab/themes/@jupyterlab/theme-light-extension/index.css
# |DEBUG|200 GET /lab/api/themes/@jupyterlab/theme-light-extension/index.css (127.0.0.1) 1.98ms
# |DEBUG|Yarn configuration loaded.
# |INFO|Build is up to date
# |DEBUG|200 GET /lab/api/build?1599369221937 (127.0.0.1) 321.97ms
# |DEBUG|200 GET /lab/api/listings/@jupyterlab/extensionmanager-extension/listings.json?1599369222151 (127.0.0.1) 0.63ms
# |DEBUG|200 GET /lab/api/workspaces/lab?1599369222177 (127.0.0.1) 0.92ms
# |DEBUG|200 GET /lab/api/settings/@jupyterlab/docmanager-extension:plugin?1599369222252 (127.0.0.1) 1.79ms
# |DEBUG|Yarn configuration loaded.
# |DEBUG|200 GET /lab/api/extensions?1599369222565 (127.0.0.1) 230.10ms
# |DEBUG|200 GET /lab/api/settings/?1599369222578 (127.0.0.1) 16.31ms
# |DEBUG|204 PUT /lab/api/workspaces/lab?1599369223138 (127.0.0.1) 1.33ms
# |DEBUG|Serving kernel resource from: /usr/local/share/jupyter/kernels/python2
# |DEBUG|200 GET /kernelspecs/python2/logo-64x64.png (127.0.0.1) 3.53ms
# |DEBUG|Serving kernel resource from: /usr/local/share/jupyter/kernels/python3
# |DEBUG|200 GET /kernelspecs/python3/logo-64x64.png (127.0.0.1) 2.34ms
# |DEBUG|Serving kernel resource from: /usr/local/share/jupyter/kernels/ir
# |DEBUG|200 GET /kernelspecs/ir/logo-64x64.png (127.0.0.1) 2.65ms
# |DEBUG|200 GET /api/contents/?content=1&1599369223448 (127.0.0.1) 2.30ms
# |DEBUG|200 GET /lab/api/extensions?1599369223570 (127.0.0.1) 1.89ms
# |DEBUG|204 PUT /lab/api/workspaces/lab?1599369223971 (127.0.0.1) 1.27ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369227391 (127.0.0.1) 1.73ms referer=http://localhost:8888/lab?
# |INFO|Creating new notebook in /
# |DEBUG|Saving /content/Untitled.ipynb
# |INFO|Writing notebook-signing key to /root/.local/share/jupyter/notebook_secret
# |DEBUG|201 POST /api/contents/?1599369231019 (127.0.0.1) 145.75ms
# |DEBUG|200 GET /api/contents/?content=1&1599369231421 (127.0.0.1) 1.94ms
# |DEBUG|200 GET /api/contents/Untitled.ipynb?content=0&1599369231420 (127.0.0.1) 0.86ms
# |DEBUG|200 GET /api/contents/Untitled.ipynb?type=notebook&content=1&1599369231718 (127.0.0.1) 10.55ms
# |DEBUG|200 GET /api/contents/?content=1&1599369231865 (127.0.0.1) 1.91ms
# |DEBUG|200 GET /api/contents/Untitled.ipynb/checkpoints?1599369232001 (127.0.0.1) 1.21ms
# |DEBUG|200 GET /api/contents/Untitled.ipynb/checkpoints?1599369232002 (127.0.0.1) 0.87ms
# |DEBUG|200 GET /api/contents/Untitled.ipynb/checkpoints?1599369232017 (127.0.0.1) 0.81ms
# |DEBUG|200 GET /api/kernels?1599369232075 (127.0.0.1) 0.91ms
# |DEBUG|200 GET /api/terminals?1599369232077 (127.0.0.1) 0.65ms
# |DEBUG|200 GET /api/sessions?1599369232077 (127.0.0.1) 0.71ms
# |DEBUG|200 GET /api/sessions?1599369232271 (127.0.0.1) 0.98ms
# |DEBUG|204 PUT /lab/api/workspaces/lab?1599369232367 (127.0.0.1) 1.29ms
# |DEBUG|Starting kernel: ['/usr/bin/python3', '-m', 'ipykernel_launcher', '-f', '/root/.local/share/jupyter/runtime/kernel-eb0d1bdb-2d17-49d1-8557-d2088a710f11.json']
# |DEBUG|Connecting to: tcp://127.0.0.1:56123
# |DEBUG|Connecting to: tcp://127.0.0.1:58485
# |INFO|Kernel started: eb0d1bdb-2d17-49d1-8557-d2088a710f11
# |DEBUG|Kernel args: {'kernel_name': 'python3', 'cwd': '/content'}
# |DEBUG|201 POST /api/sessions?1599369232534 (127.0.0.1) 42.60ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369232649 (127.0.0.1) 3.05ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/sessions?1599369232838 (127.0.0.1) 6.18ms
# |DEBUG|200 PATCH /api/sessions/c4ff530c-54c0-4e7f-9e3d-6597d5d20384?1599369233098 (127.0.0.1) 2.04ms
# |DEBUG|200 GET /api/kernels?1599369233109 (127.0.0.1) 1.12ms
# |DEBUG|Initializing websocket connection /api/kernels/eb0d1bdb-2d17-49d1-8557-d2088a710f11/channels
# |DEBUG|Requesting kernel info from eb0d1bdb-2d17-49d1-8557-d2088a710f11
# |DEBUG|Connecting to: tcp://127.0.0.1:55997
# |DEBUG|200 PATCH /api/sessions/c4ff530c-54c0-4e7f-9e3d-6597d5d20384?1599369233354 (127.0.0.1) 1.80ms
# |DEBUG|200 GET /api/sessions?1599369233356 (127.0.0.1) 1.10ms
# |DEBUG|activity on eb0d1bdb-2d17-49d1-8557-d2088a710f11: status
# |DEBUG|activity on eb0d1bdb-2d17-49d1-8557-d2088a710f11: status
# |DEBUG|activity on eb0d1bdb-2d17-49d1-8557-d2088a710f11: status
# |DEBUG|Received kernel info: {'status': 'ok', 'protocol_version': '5.1', 'implementation': 'ipython', 'implementation_version': '5.5.0', 'language_info': {'name': 'python', 'version': '3.6.9', 'mimetype': 'text/x-python', 'codemirror_mode': {'name': 'ipython', 'version': 3}, 'pygments_lexer': 'ipython3', 'nbconvert_exporter': 'python', 'file_extension': '.py'}, 'banner': 'Python 3.6.9 (default, Jul 17 2020, 12:50:27) \nType "copyright", "credits" or "license" for more information.\n\nIPython 5.5.0 -- An enhanced Interactive Python.\n?         -> Introduction and overview of IPython\'s features.\n%quickref -> Quick reference.\nhelp      -> Python\'s own help system.\nobject?   -> Details about \'object\', use \'object??\' for extra details.\n', 'help_links': [{'text': 'Python Reference', 'url': 'https://docs.python.org/3.6'}, {'text': 'IPython Reference', 'url': 'https://ipython.org/documentation.html'}, {'text': 'NumPy Reference', 'url': 'https://docs.scipy.org/doc/numpy/reference/'}, {'text': 'SciPy Reference', 'url': 'https://docs.scipy.org/doc/scipy/reference/'}, {'text': 'Matplotlib Reference', 'url': 'https://matplotlib.org/contents.html'}, {'text': 'SymPy Reference', 'url': 'http://docs.sympy.org/latest/index.html'}, {'text': 'pandas Reference', 'url': 'https://pandas.pydata.org/pandas-docs/stable/'}]}
# |INFO|Adapting to protocol v5.1 for kernel eb0d1bdb-2d17-49d1-8557-d2088a710f11
# |DEBUG|101 GET /api/kernels/eb0d1bdb-2d17-49d1-8557-d2088a710f11/channels?session_id=07afb833-d437-43a1-b632-4590b9c5a4b7 (127.0.0.1) 263.97ms
# |DEBUG|Opening websocket /api/kernels/eb0d1bdb-2d17-49d1-8557-d2088a710f11/channels
# |DEBUG|Getting buffer for eb0d1bdb-2d17-49d1-8557-d2088a710f11
# |DEBUG|Connecting to: tcp://127.0.0.1:55997
# |DEBUG|Connecting to: tcp://127.0.0.1:58485
# |DEBUG|Connecting to: tcp://127.0.0.1:52771
# |DEBUG|Found kernel python2 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel python3 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel ir in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel swift in /usr/local/share/jupyter/kernels
# |DEBUG|200 GET /api/kernelspecs?1599369233615 (127.0.0.1) 2.86ms
# |DEBUG|Initializing websocket connection /api/kernels/eb0d1bdb-2d17-49d1-8557-d2088a710f11/channels
# |INFO|Adapting to protocol v5.1 for kernel eb0d1bdb-2d17-49d1-8557-d2088a710f11
# |DEBUG|101 GET /api/kernels/eb0d1bdb-2d17-49d1-8557-d2088a710f11/channels?session_id=d6a8fea8-9de7-438c-b6a8-da15c1e7ad94 (127.0.0.1) 2.36ms
# |DEBUG|Opening websocket /api/kernels/eb0d1bdb-2d17-49d1-8557-d2088a710f11/channels
# |DEBUG|Getting buffer for eb0d1bdb-2d17-49d1-8557-d2088a710f11
# |DEBUG|Connecting to: tcp://127.0.0.1:55997
# |DEBUG|Connecting to: tcp://127.0.0.1:58485
# |DEBUG|Connecting to: tcp://127.0.0.1:52771
# |DEBUG|activity on eb0d1bdb-2d17-49d1-8557-d2088a710f11: status
# |DEBUG|activity on eb0d1bdb-2d17-49d1-8557-d2088a710f11: status
# |DEBUG|activity on eb0d1bdb-2d17-49d1-8557-d2088a710f11: status
# |DEBUG|activity on eb0d1bdb-2d17-49d1-8557-d2088a710f11: status
# |DEBUG|Path base/images/favicon-busy-1.ico served from /usr/local/lib/python3.6/dist-packages/notebook/static/base/images/favicon-busy-1.ico
# |DEBUG|200 GET /static/base/images/favicon-busy-1.ico (127.0.0.1) 2.10ms
# |DEBUG|Websocket closed eb0d1bdb-2d17-49d1-8557-d2088a710f11:07afb833-d437-43a1-b632-4590b9c5a4b7
# |DEBUG|Initializing websocket connection /api/kernels/eb0d1bdb-2d17-49d1-8557-d2088a710f11/channels
# |INFO|Adapting to protocol v5.1 for kernel eb0d1bdb-2d17-49d1-8557-d2088a710f11
# |DEBUG|101 GET /api/kernels/eb0d1bdb-2d17-49d1-8557-d2088a710f11/channels?session_id=8c8a0d62-d537-42f5-b909-3b34381b2a78 (127.0.0.1) 2.47ms
# |DEBUG|Opening websocket /api/kernels/eb0d1bdb-2d17-49d1-8557-d2088a710f11/channels
# |DEBUG|Getting buffer for eb0d1bdb-2d17-49d1-8557-d2088a710f11
# |DEBUG|Connecting to: tcp://127.0.0.1:55997
# |DEBUG|Connecting to: tcp://127.0.0.1:58485
# |DEBUG|Connecting to: tcp://127.0.0.1:52771
# |DEBUG|200 GET /api/kernels?1599369234135 (127.0.0.1) 0.78ms
# |DEBUG|200 GET /api/sessions?1599369234134 (127.0.0.1) 0.74ms
# |DEBUG|304 GET /static/base/images/favicon-busy-1.ico (127.0.0.1) 0.89ms
# |DEBUG|activity on eb0d1bdb-2d17-49d1-8557-d2088a710f11: status
# |DEBUG|activity on eb0d1bdb-2d17-49d1-8557-d2088a710f11: status
# |DEBUG|304 GET /static/base/images/favicon-busy-1.ico (127.0.0.1) 0.77ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369237904 (127.0.0.1) 1.55ms referer=http://localhost:8888/lab?
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369243532 (127.0.0.1) 1.52ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/kernels?1599369244392 (127.0.0.1) 1.08ms
# |DEBUG|200 GET /api/sessions?1599369244393 (127.0.0.1) 0.79ms
# |DEBUG|200 GET /api/contents/?content=1&1599369246519 (127.0.0.1) 2.03ms
# |DEBUG|200 GET /api/contents/?content=1&1599369256790 (127.0.0.1) 1.93ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369260586 (127.0.0.1) 1.51ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/terminals?1599369263591 (127.0.0.1) 0.84ms
# |DEBUG|200 GET /api/contents/drive?content=1&1599369265103 (127.0.0.1) 2.31ms
# |DEBUG|200 GET /api/kernels?1599369265585 (127.0.0.1) 1.12ms
# |DEBUG|200 GET /api/sessions?1599369265587 (127.0.0.1) 1.23ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369265840 (127.0.0.1) 1.47ms referer=http://localhost:8888/lab?
# |DEBUG|204 PUT /lab/api/workspaces/lab?1599369265860 (127.0.0.1) 5.97ms
# |DEBUG|200 GET /api/contents/drive?content=1&1599369267049 (127.0.0.1) 2.47ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369267310 (127.0.0.1) 6.80ms
# |DEBUG|204 PUT /lab/api/workspaces/lab?1599369268074 (127.0.0.1) 1.29ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369271097 (127.0.0.1) 1.59ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/drive?content=1&1599369271219 (127.0.0.1) 2.54ms
# |DEBUG|204 PUT /lab/api/workspaces/lab?1599369271990 (127.0.0.1) 1.40ms
# |DEBUG|200 GET /api/terminals?1599369273846 (127.0.0.1) 0.85ms
# |DEBUG|200 GET /api/contents/?content=1&1599369273976 (127.0.0.1) 1.80ms
# |DEBUG|204 PUT /lab/api/workspaces/lab?1599369274731 (127.0.0.1) 1.24ms
# |DEBUG|200 GET /api/kernels?1599369275843 (127.0.0.1) 0.92ms
# |DEBUG|200 GET /api/sessions?1599369275844 (127.0.0.1) 0.76ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369276356 (127.0.0.1) 1.55ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/?content=1&1599369277322 (127.0.0.1) 1.90ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369281618 (127.0.0.1) 1.61ms referer=http://localhost:8888/lab?
# |DEBUG|Found kernel python2 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel python3 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel ir in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel swift in /usr/local/share/jupyter/kernels
# |DEBUG|200 GET /api/kernelspecs?1599369283399 (127.0.0.1) 2.87ms
# |DEBUG|200 GET /api/terminals?1599369284116 (127.0.0.1) 0.81ms
# |DEBUG|200 GET /api/sessions?1599369286112 (127.0.0.1) 0.99ms
# |DEBUG|200 GET /api/kernels?1599369286111 (127.0.0.1) 0.71ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369286877 (127.0.0.1) 1.55ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/?content=1&1599369287579 (127.0.0.1) 2.06ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369292137 (127.0.0.1) 1.62ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/terminals?1599369294379 (127.0.0.1) 0.82ms
# |DEBUG|200 GET /api/kernels?1599369296374 (127.0.0.1) 1.02ms
# |DEBUG|200 GET /api/sessions?1599369296373 (127.0.0.1) 1.00ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369297392 (127.0.0.1) 1.55ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/?content=1&1599369297843 (127.0.0.1) 2.05ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369302648 (127.0.0.1) 1.52ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/drive?content=1&1599369303095 (127.0.0.1) 2.43ms
# |DEBUG|204 PUT /lab/api/workspaces/lab?1599369303860 (127.0.0.1) 1.34ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369304126 (127.0.0.1) 5.32ms
# |DEBUG|200 GET /api/terminals?1599369304645 (127.0.0.1) 0.78ms
# |DEBUG|204 PUT /lab/api/workspaces/lab?1599369304887 (127.0.0.1) 1.31ms
# |DEBUG|200 GET /api/kernels?1599369306629 (127.0.0.1) 0.94ms
# |DEBUG|200 GET /api/sessions?1599369306631 (127.0.0.1) 0.75ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369307904 (127.0.0.1) 1.50ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369308101 (127.0.0.1) 5.34ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369313160 (127.0.0.1) 1.52ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/Untitled.ipynb?content=0&1599369314272 (127.0.0.1) 1.93ms
# |INFO|Saving file at /Untitled.ipynb
# |DEBUG|Saving /content/Untitled.ipynb
# |DEBUG|200 PUT /api/contents/Untitled.ipynb?1599369314531 (127.0.0.1) 17.42ms
# |DEBUG|200 GET /api/contents/Untitled.ipynb/checkpoints?1599369314801 (127.0.0.1) 1.36ms
# |DEBUG|201 POST /api/contents/Untitled.ipynb/checkpoints?1599369314802 (127.0.0.1) 1.12ms
# |DEBUG|200 GET /api/terminals?1599369314901 (127.0.0.1) 0.68ms
# |DEBUG|200 GET /api/sessions?1599369316887 (127.0.0.1) 1.07ms
# |DEBUG|200 GET /api/kernels?1599369316888 (127.0.0.1) 0.65ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369318362 (127.0.0.1) 5.89ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369318417 (127.0.0.1) 1.44ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/Untitled.ipynb?content=0&1599369321827 (127.0.0.1) 1.16ms
# |INFO|Saving file at /Untitled.ipynb
# |DEBUG|Saving /content/Untitled.ipynb
# |DEBUG|200 PUT /api/contents/Untitled.ipynb?1599369322084 (127.0.0.1) 17.82ms
# |DEBUG|200 GET /api/contents/Untitled.ipynb/checkpoints?1599369322355 (127.0.0.1) 1.12ms
# |DEBUG|201 POST /api/contents/Untitled.ipynb/checkpoints?1599369322356 (127.0.0.1) 1.09ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369323686 (127.0.0.1) 1.49ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/terminals?1599369325157 (127.0.0.1) 0.79ms
# |DEBUG|200 GET /api/sessions?1599369327142 (127.0.0.1) 0.98ms
# |DEBUG|200 GET /api/kernels?1599369327143 (127.0.0.1) 0.70ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369328640 (127.0.0.1) 4.97ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369328946 (127.0.0.1) 1.64ms referer=http://localhost:8888/lab?
# |DEBUG|204 PUT /lab/api/workspaces/lab?1599369330756 (127.0.0.1) 1.35ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369334219 (127.0.0.1) 1.63ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/terminals?1599369335414 (127.0.0.1) 0.83ms
# |INFO|Creating new notebook in /drive/My Drive
# |DEBUG|Saving /content/drive/My Drive/Untitled.ipynb
# |DEBUG|201 POST /api/contents/drive/My%20Drive?1599369335671 (127.0.0.1) 30.07ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369335958 (127.0.0.1) 6.58ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive/Untitled.ipynb?content=0&1599369335956 (127.0.0.1) 1.40ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive/Untitled.ipynb?type=notebook&content=1&1599369336248 (127.0.0.1) 12.73ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369336328 (127.0.0.1) 5.43ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive/Untitled.ipynb/checkpoints?1599369336530 (127.0.0.1) 1.74ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive/Untitled.ipynb/checkpoints?1599369336532 (127.0.0.1) 1.26ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive/Untitled.ipynb/checkpoints?1599369336544 (127.0.0.1) 1.62ms
# |DEBUG|200 GET /api/sessions?1599369336788 (127.0.0.1) 1.33ms
# |DEBUG|204 PUT /lab/api/workspaces/lab?1599369336832 (127.0.0.1) 1.07ms
# |DEBUG|Starting kernel: ['/usr/bin/python3', '-m', 'ipykernel_launcher', '-f', '/root/.local/share/jupyter/runtime/kernel-b5a62c36-0e63-4aca-ba82-21ef223b6922.json']
# |DEBUG|Connecting to: tcp://127.0.0.1:45753
# |DEBUG|Connecting to: tcp://127.0.0.1:44761
# |INFO|Kernel started: b5a62c36-0e63-4aca-ba82-21ef223b6922
# |DEBUG|Kernel args: {'kernel_name': 'python3', 'cwd': '/content/drive/My Drive'}
# |DEBUG|201 POST /api/sessions?1599369337041 (127.0.0.1) 19.73ms
# |DEBUG|200 GET /api/sessions?1599369337325 (127.0.0.1) 1.88ms
# |DEBUG|200 GET /api/kernels?1599369337543 (127.0.0.1) 1.25ms
# |DEBUG|200 PATCH /api/sessions/7cc08168-3b05-4027-9b83-b26860fceba3?1599369337584 (127.0.0.1) 1.33ms
# |DEBUG|200 GET /api/kernels?1599369337594 (127.0.0.1) 0.96ms
# |DEBUG|Initializing websocket connection /api/kernels/b5a62c36-0e63-4aca-ba82-21ef223b6922/channels
# |DEBUG|Requesting kernel info from b5a62c36-0e63-4aca-ba82-21ef223b6922
# |DEBUG|Connecting to: tcp://127.0.0.1:55047
# |DEBUG|200 GET /api/sessions?1599369337842 (127.0.0.1) 1.33ms
# |DEBUG|200 PATCH /api/sessions/7cc08168-3b05-4027-9b83-b26860fceba3?1599369337839 (127.0.0.1) 1.35ms
# |DEBUG|activity on b5a62c36-0e63-4aca-ba82-21ef223b6922: status
# |DEBUG|activity on b5a62c36-0e63-4aca-ba82-21ef223b6922: status
# |DEBUG|activity on b5a62c36-0e63-4aca-ba82-21ef223b6922: status
# |DEBUG|Received kernel info: {'status': 'ok', 'protocol_version': '5.1', 'implementation': 'ipython', 'implementation_version': '5.5.0', 'language_info': {'name': 'python', 'version': '3.6.9', 'mimetype': 'text/x-python', 'codemirror_mode': {'name': 'ipython', 'version': 3}, 'pygments_lexer': 'ipython3', 'nbconvert_exporter': 'python', 'file_extension': '.py'}, 'banner': 'Python 3.6.9 (default, Jul 17 2020, 12:50:27) \nType "copyright", "credits" or "license" for more information.\n\nIPython 5.5.0 -- An enhanced Interactive Python.\n?         -> Introduction and overview of IPython\'s features.\n%quickref -> Quick reference.\nhelp      -> Python\'s own help system.\nobject?   -> Details about \'object\', use \'object??\' for extra details.\n', 'help_links': [{'text': 'Python Reference', 'url': 'https://docs.python.org/3.6'}, {'text': 'IPython Reference', 'url': 'https://ipython.org/documentation.html'}, {'text': 'NumPy Reference', 'url': 'https://docs.scipy.org/doc/numpy/reference/'}, {'text': 'SciPy Reference', 'url': 'https://docs.scipy.org/doc/scipy/reference/'}, {'text': 'Matplotlib Reference', 'url': 'https://matplotlib.org/contents.html'}, {'text': 'SymPy Reference', 'url': 'http://docs.sympy.org/latest/index.html'}, {'text': 'pandas Reference', 'url': 'https://pandas.pydata.org/pandas-docs/stable/'}]}
# |INFO|Adapting to protocol v5.1 for kernel b5a62c36-0e63-4aca-ba82-21ef223b6922
# |DEBUG|101 GET /api/kernels/b5a62c36-0e63-4aca-ba82-21ef223b6922/channels?session_id=10bad2d8-8ca2-427d-99f9-07a927929936 (127.0.0.1) 197.19ms
# |DEBUG|Opening websocket /api/kernels/b5a62c36-0e63-4aca-ba82-21ef223b6922/channels
# |DEBUG|Getting buffer for b5a62c36-0e63-4aca-ba82-21ef223b6922
# |DEBUG|Connecting to: tcp://127.0.0.1:55047
# |DEBUG|Connecting to: tcp://127.0.0.1:44761
# |DEBUG|Connecting to: tcp://127.0.0.1:51667
# |DEBUG|Found kernel python2 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel python3 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel ir in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel swift in /usr/local/share/jupyter/kernels
# |DEBUG|200 GET /api/kernelspecs?1599369338097 (127.0.0.1) 3.13ms
# |DEBUG|activity on b5a62c36-0e63-4aca-ba82-21ef223b6922: status
# |DEBUG|activity on b5a62c36-0e63-4aca-ba82-21ef223b6922: status
# |DEBUG|304 GET /static/base/images/favicon-busy-1.ico (127.0.0.1) 0.81ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369339476 (127.0.0.1) 1.77ms referer=http://localhost:8888/lab?
# |DEBUG|Found kernel python2 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel python3 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel ir in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel swift in /usr/local/share/jupyter/kernels
# |DEBUG|200 GET /api/kernelspecs?1599369344658 (127.0.0.1) 2.82ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369344738 (127.0.0.1) 1.44ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/terminals?1599369345684 (127.0.0.1) 0.89ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369346601 (127.0.0.1) 5.67ms
# |DEBUG|200 GET /api/kernels?1599369347865 (127.0.0.1) 0.94ms
# |DEBUG|200 GET /api/sessions?1599369348111 (127.0.0.1) 1.02ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369350006 (127.0.0.1) 1.56ms referer=http://localhost:8888/lab?
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369355275 (127.0.0.1) 1.57ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/terminals?1599369355956 (127.0.0.1) 0.81ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369356887 (127.0.0.1) 5.80ms
# |DEBUG|200 GET /api/kernels?1599369358123 (127.0.0.1) 0.98ms
# |DEBUG|200 GET /api/sessions?1599369358366 (127.0.0.1) 1.12ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369360538 (127.0.0.1) 1.58ms referer=http://localhost:8888/lab?
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369365802 (127.0.0.1) 1.48ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/terminals?1599369366213 (127.0.0.1) 0.78ms
# |DEBUG|200 GET /api/terminals?1599369386588 (127.0.0.1) 0.78ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369386590 (127.0.0.1) 1.26ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369387598 (127.0.0.1) 6.10ms
# |DEBUG|200 GET /api/sessions?1599369389603 (127.0.0.1) 1.06ms
# |DEBUG|200 GET /api/kernels?1599369389601 (127.0.0.1) 0.72ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369391853 (127.0.0.1) 1.63ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/terminals?1599369396859 (127.0.0.1) 0.77ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369397107 (127.0.0.1) 1.50ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369397863 (127.0.0.1) 5.97ms
# |DEBUG|200 GET /api/sessions?1599369399862 (127.0.0.1) 1.02ms
# |DEBUG|200 GET /api/kernels?1599369399863 (127.0.0.1) 0.68ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369402365 (127.0.0.1) 1.62ms referer=http://localhost:8888/lab?
# |DEBUG|Found kernel python2 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel python3 in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel ir in /usr/local/share/jupyter/kernels
# |DEBUG|Found kernel swift in /usr/local/share/jupyter/kernels
# |DEBUG|200 GET /api/kernelspecs?1599369405930 (127.0.0.1) 3.09ms
# |DEBUG|200 GET /api/terminals?1599369407126 (127.0.0.1) 0.76ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369407622 (127.0.0.1) 1.45ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369408136 (127.0.0.1) 5.88ms
# |DEBUG|200 GET /api/kernels?1599369410128 (127.0.0.1) 0.97ms
# |DEBUG|200 GET /api/sessions?1599369410126 (127.0.0.1) 0.82ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369412891 (127.0.0.1) 1.81ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/terminals?1599369417381 (127.0.0.1) 0.79ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369418147 (127.0.0.1) 1.48ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369418401 (127.0.0.1) 5.61ms
# |DEBUG|200 GET /api/sessions?1599369420393 (127.0.0.1) 1.04ms
# |DEBUG|200 GET /api/kernels?1599369420391 (127.0.0.1) 0.69ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369423415 (127.0.0.1) 1.56ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/terminals?1599369427645 (127.0.0.1) 0.77ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369428669 (127.0.0.1) 6.40ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369428673 (127.0.0.1) 1.49ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/sessions?1599369430666 (127.0.0.1) 1.10ms
# |DEBUG|200 GET /api/kernels?1599369430668 (127.0.0.1) 0.69ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369434003 (127.0.0.1) 1.50ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/terminals?1599369437903 (127.0.0.1) 0.79ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive?content=1&1599369438931 (127.0.0.1) 5.84ms
# |DEBUG|Using contents: services/contents
# |WARNING|404 GET /metrics?1599369439269 (127.0.0.1) 1.71ms referer=http://localhost:8888/lab?
# |DEBUG|200 GET /api/contents/drive/My%20Drive/Untitled.ipynb?content=0&1599369456588 (127.0.0.1) 2.09ms
# |INFO|Saving file at /drive/My Drive/Untitled.ipynb
# |DEBUG|Saving /content/drive/My Drive/Untitled.ipynb
# |DEBUG|200 PUT /api/contents/drive/My%20Drive/Untitled.ipynb?1599369456849 (127.0.0.1) 28.03ms
# |DEBUG|200 GET /api/contents/drive/My%20Drive/Untitled.ipynb/checkpoints?1599369457136 (127.0.0.1) 1.55ms
# |DEBUG|Websocket closed eb0d1bdb-2d17-49d1-8557-d2088a710f11:8c8a0d62-d537-42f5-b909-3b34381b2a78
# |DEBUG|Websocket closed eb0d1bdb-2d17-49d1-8557-d2088a710f11:d6a8fea8-9de7-438c-b6a8-da15c1e7ad94
# |INFO|Starting buffering for eb0d1bdb-2d17-49d1-8557-d2088a710f11:d6a8fea8-9de7-438c-b6a8-da15c1e7ad94
# |DEBUG|Clearing buffer for eb0d1bdb-2d17-49d1-8557-d2088a710f11
# |DEBUG|Websocket closed b5a62c36-0e63-4aca-ba82-21ef223b6922:10bad2d8-8ca2-427d-99f9-07a927929936
# |INFO|Starting buffering for b5a62c36-0e63-4aca-ba82-21ef223b6922:10bad2d8-8ca2-427d-99f9-07a927929936
# |DEBUG|Clearing buffer for b5a62c36-0e63-4aca-ba82-21ef223b6922

# %% [markdown]
# ```
# #	$OpenBSD: sshd_config,v 1.101 2017/03/14 07:19:07 djm Exp $
#
# # This is the sshd server system-wide configuration file.  See
# # sshd_config(5) for more information.
#
# # This sshd was compiled with PATH=/usr/bin:/bin:/usr/sbin:/sbin
#
# # The strategy used for options in the default sshd_config shipped with
# # OpenSSH is to specify options with their default value where
# # possible, but leave them commented.  Uncommented options override the
# # default value.
#
# #Port 22
# #AddressFamily any
# #ListenAddress 0.0.0.0
# #ListenAddress ::
#
# #HostKey /etc/ssh/ssh_host_rsa_key
# #HostKey /etc/ssh/ssh_host_ecdsa_key
# #HostKey /etc/ssh/ssh_host_ed25519_key
#
# # Ciphers and keying
# #RekeyLimit default none
#
# # Logging
# #SyslogFacility AUTH
# #LogLevel INFO
#
# # Authentication:
#
# #LoginGraceTime 2m
# #PermitRootLogin prohibit-password
# #StrictModes yes
# #MaxAuthTries 6
# #MaxSessions 10
#
# PubkeyAuthentication yes
#
# # Expect .ssh/authorized_keys2 to be disregarded by default in future.
# AuthorizedKeysFile	.ssh/authorized_keys .ssh/authorized_keys2
#
# #AuthorizedPrincipalsFile none
#
# #AuthorizedKeysCommand none
# #AuthorizedKeysCommandUser nobody
#
# # For this to work you will also need host keys in /etc/ssh/ssh_known_hosts
# #HostbasedAuthentication no
# # Change to yes if you don't trust ~/.ssh/known_hosts for
# # HostbasedAuthentication
# #IgnoreUserKnownHosts no
# # Don't read the user's ~/.rhosts and ~/.shosts files
# #IgnoreRhosts yes
#
# # To disable tunneled clear text passwords, change to no here!
# #PasswordAuthentication yes
# #PermitEmptyPasswords no
#
# # Change to yes to enable challenge-response passwords (beware issues with
# # some PAM modules and threads)
# ChallengeResponseAuthentication no
#
# # Kerberos options
# #KerberosAuthentication no
# #KerberosOrLocalPasswd yes
# #KerberosTicketCleanup yes
# #KerberosGetAFSToken no
#
# # GSSAPI options
# #GSSAPIAuthentication no
# #GSSAPICleanupCredentials yes
# #GSSAPIStrictAcceptorCheck yes
# #GSSAPIKeyExchange no
#
# # Set this to 'yes' to enable PAM authentication, account processing,
# # and session processing. If this is enabled, PAM authentication will
# # be allowed through the ChallengeResponseAuthentication and
# # PasswordAuthentication.  Depending on your PAM configuration,
# # PAM authentication via ChallengeResponseAuthentication may bypass
# # the setting of "PermitRootLogin without-password".
# # If you just want the PAM account and session checks to run without
# # PAM authentication, then enable this but set PasswordAuthentication
# # and ChallengeResponseAuthentication to 'no'.
# UsePAM yes
#
# #AllowAgentForwarding yes
# #AllowTcpForwarding yes
# #GatewayPorts no
# X11Forwarding yes
# #X11DisplayOffset 10
# #X11UseLocalhost yes
# #PermitTTY yes
# PrintMotd no
# #PrintLastLog yes
# #TCPKeepAlive yes
# #UseLogin no
# #PermitUserEnvironment no
# #Compression delayed
# #ClientAliveInterval 0
# #ClientAliveCountMax 3
# #UseDNS no
# #PidFile /var/run/sshd.pid
# #MaxStartups 10:30:100
# #PermitTunnel no
# #ChrootDirectory none
# #VersionAddendum none
#
# # no default banner path
# #Banner none
#
# # Allow client to pass locale environment variables
# AcceptEnv LANG LC_*
#
# # override default of no subsystems
# Subsystem	sftp	/usr/lib/openssh/sftp-server
#
# # Example of overriding settings on a per-user basis
# #Match User anoncvs
# #	X11Forwarding no
# #	AllowTcpForwarding no
# #	PermitTTY no
# #	ForceCommand cvs server
# PermitRootLogin yes
# PasswordAuthentication yes
# ```
